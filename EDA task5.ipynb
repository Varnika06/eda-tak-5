# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Varni\Downloads\Varnika.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.nunique() #used to find no. of unique entries in all columns
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df.isnull().sum() #no null value
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe().T #Provide a statistics summary of data belonging to numerical datatype
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns=df.columns.str.replace('/','_')
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
print(df.gender.unique())  #finding unique values from all columns
print(df.race_ethnicity.unique())
print(df.parental_level_of_education.unique())
print(df.lunch.unique())
print(df.test_preparation_course.unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
gender_race_counts=df.groupby(['race_ethnicity','gender']).size().unstack() #plotting relation between gender and race

# %%
gender_race_counts.plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
#this graph shows the no. of females and males in various groups

# %%
gender_parents_counts=df.groupby(['parental_level_of_education','gender']).size().unstack()

# %%
gender_parents_counts.plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
#this grapgh shows no. of females and males segregated on the basis of parental level of education

# %%
gender_lunch_counts=df.groupby(['lunch','gender']).size().unstack()

# %%
gender_lunch_counts.plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
#this grapgh shows the no. of females and males segregated on the basis of type of lunch

# %%
gender_test_counts=df.groupby(['test_preparation_course','gender']).size().unstack()

# %%
gender_test_counts.plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
# this tells us the no. of females and males who have either completed the test course or have not

# %%
gender_math_counts=df.groupby(['math_score','gender']).size().unstack()

# %%
gender_math_counts.plot(kind='hist')
plt.ylabel('count')
plt.show()

# %%
#this tells us the range of math marks scored by females and males separately

# %%
gender_reading_counts=df.groupby(['reading_score','gender']).size().unstack()

# %%
gender_reading_counts.plot(kind='hist')
plt.ylabel('count')
plt.show() #this tells us the range of reading marks scored by females and males separately

# %%
gender_writing_counts=df.groupby(['writing_score','gender']).size().unstack()

# %%
gender_writing_counts.plot(kind='hist')
plt.ylabel('count')
plt.show() #this tells us the range of writing marks scored by females and males separately

# %%
race_parents_counts=df.groupby(['race_ethnicity','parental_level_of_education']).size().unstack()

# %%
race_parents_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows the parental level of education of students in various groups

# %%
race_lunch_counts=df.groupby(['race_ethnicity','lunch']).size().unstack()

# %%
race_lunch_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows the no. of students in various groups having a particular type of lunch

# %%
race_test_counts=df.groupby(['race_ethnicity','test_preparation_course']).size().unstack()

# %%
race_test_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows the no. of students in various groups who have either completed the course or not

# %%
race_math_counts=df.groupby(['race_ethnicity','math_score']).size().unstack()

# %%
race_math_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows the math marks of students in various groups

# %%
race_reading_counts=df.groupby(['race_ethnicity','reading_score']).size().unstack()

# %%
race_reading_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows reading marks of students in various groups

# %%
race_writing_counts=df.groupby(['race_ethnicity','writing_score']).size().unstack()

# %%
race_writing_counts.plot(kind='bar')
plt.ylabel('count')
plt.show() #shows writing marks of students in various groups
